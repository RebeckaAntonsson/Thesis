# %%
import pandas as pd
from scipy.stats import spearmanr

# %%
# Read several csv files with the same format, but different names, into one df
biophi = pd.read_csv("../Testing_settings_for_tools/BioPhi(OASis)/ranked_score_table.csv")
netMHCpan_EL = pd.read_csv("../Testing_settings_for_tools/NetMHCpan_EL/ranked_score_table.csv")
netMHCpan_BA = pd.read_csv("../Testing_settings_for_tools/NetMHCpan_BA/ranked_score_table.csv")
netMHCpan_immunogen = pd.read_csv("../Testing_settings_for_tools/NetMHCpanImmunogen/ranked_score_table.csv")

# %%
# Create new df with all dfs loaded above stacked on each other (they have the same colums so just add them as rows)
all_toolANDsettings = pd.concat([biophi, netMHCpan_EL, netMHCpan_BA,netMHCpan_immunogen], ignore_index=True)

# Sort based on sum_MARE
all_toolANDsettings = all_toolANDsettings.sort_values(by='spearmanr', ascending=False)
all_toolANDsettings
# Out:
#                                    dataframe  sum_MARE  spearmanr  \
# 39  netMHCpan_immunogen_peptide_length_14_AB     358.0   0.329303
# 38  netMHCpan_immunogen_peptide_length_13_AB     358.0   0.321005
# 40    netMHCpan_immunogen_all_pep_lengths_AB     388.0   0.242295
# 35  netMHCpan_immunogen_peptide_length_10_AB     401.0   0.198684
# 36  netMHCpan_immunogen_peptide_length_11_AB     390.0   0.195128
# 37  netMHCpan_immunogen_peptide_length_12_AB     399.0   0.181495
# 34   netMHCpan_immunogen_peptide_length_9_AB     402.0   0.151740
# 20                netMHCpan_EL_peplength9_AB     418.0   0.140004
# 33   netMHCpan_immunogen_peptide_length_8_AB     429.0   0.086658
# 2                     NrKab_CDRKab_Medium_AB     439.0   0.070535
# 10                   NrKAB_CDRChot_Strict_AB     426.0   0.069938
# 12                  NrKAB_CDRNorth_Strict_AB     426.0   0.069938
# 11                   NrKAB_CDRIMGT_Strict_AB     426.0   0.069938
# 17                   NrIMGT_CDRKAB_Strict_AB     426.0   0.069938
# 18                    NrAHo_CDRKAB_Strict_AB     426.0   0.069938
# 16                   NrChot_CDRKAB_Strict_AB     426.0   0.069938
# 3                     NrKab_CDRKab_Strict_AB     426.0   0.069938
# 15                   NrKAB_CDRNorth_Loose_AB     436.0   0.050501
# 13                    NrKAB_CDRChot_Loose_AB     436.0   0.050501
# 0                      NrKab_CDRKab_Loose_AB     436.0   0.050501
# 14                    NrKAB_CDRIMGT_Loose_AB     436.0   0.050501
# 4                   NrKab_CDRChot_Relaxed_AB     448.0   0.034616
# 1                    NrKab_CDRKab_Relaxed_AB     448.0   0.034616
# 6                  NrKab_CDRNorth_Relaxed_AB     448.0   0.034616
# 5                   NrKab_CDRIMGT_Relaxed_AB     448.0   0.034616
# 8                   NrIMGT_CDRKab_Relaxed_AB     448.0   0.034616
# 7                   NrChot_CDRKab_Relaxed_AB     448.0   0.034616
# 9                    NrAHo_CDRKab_Relaxed_AB     448.0   0.034616
# 23               netMHCpan_EL_peplength12_AB     444.0   0.020155
# 19                netMHCpan_EL_peplength8_AB     441.0   0.018851
# 28               netMHCpan_BA_peplength10_AB     446.0  -0.032837
# 27                netMHCpan_BA_peplength9_AB     452.0  -0.033551
# 21               netMHCpan_EL_peplength10_AB     452.0  -0.042684
# 25               netMHCpan_EL_peplength14_AB     476.0  -0.073745
# 30               netMHCpan_BA_peplength12_AB     502.0  -0.080493
# 29               netMHCpan_BA_peplength11_AB     480.0  -0.126600
# 32               netMHCpan_BA_peplength14_AB     508.0  -0.167852
# 26                netMHCpan_BA_peplength8_AB     517.0  -0.212118
# 22               netMHCpan_EL_peplength11_AB     507.0  -0.235817
# 24               netMHCpan_EL_peplength13_AB     533.0  -0.242708
# 31               netMHCpan_BA_peplength13_AB     558.0  -0.416217
#
#     Caplacizumab_MARE  Vobarilizumab_MARE
# 39               11.0               -28.0
# 38               11.0               -23.0
# 40               11.0               -22.0
# 35               10.0               -17.0
# 36               11.0               -21.0
# 37               11.0               -18.0
# 34               11.0               -20.0
# 20                5.0                32.0
# 33               10.0               -22.0
# 2                 8.0                 7.0
# 10                8.0                 5.0
# 12                8.0                 5.0
# 11                8.0                 5.0
# 17                8.0                 5.0
# 18                8.0                 5.0
# 16                8.0                 5.0
# 3                 8.0                 5.0
# 15                8.0                 6.0
# 13                8.0                 6.0
# 0                 8.0                 6.0
# 14                8.0                 6.0
# 4                 8.0                15.0
# 1                 8.0                15.0
# 6                 8.0                15.0
# 5                 8.0                15.0
# 8                 8.0                15.0
# 7                 8.0                15.0
# 9                 8.0                15.0
# 23               11.0                14.0
# 19               11.0                35.0
# 28               11.0                29.0
# 27                9.0                21.0
# 21                7.0                27.0
# 25               16.0                 1.0
# 30               11.0                36.0
# 29                9.0                33.0
# 32               26.0                 0.0
# 26                6.0                36.0
# 22               11.0                25.0
# 24               13.0                17.0
# 31                6.0                28.0

# %%
# save it as excel file
all_toolANDsettings.to_excel("all_toolANDsettings.xlsx", index=False)
