# %% [markdown]
# # Immunogenicity tool test: Testing setttings for tools: CD4Episcore Immunogenicity score
# Author: Rebecka Antonsson\
# Version: 1 (04-03-2026)

# %% [markdown]
# # Notebook explanation
# Notebook to calculate the scores of the outputs from the tool CD4Episcire Combines score
#
# Settings tested are:\
# \
# netMHC_II_pepl11_allel27_wind2_03_03_2026.csv\
# netMHC_II_pepl12_allel27_wind2_03_03_2026.csv\
# netMHC_II_pepl12_allel27_wind5_03_03_2026.csv\
# netMHC_II_pepl12_allel27_wind10_03_03_2026.csv\
# netMHC_II_pepl15_allel27_wind2_03_03_2026.csv\
# netMHC_II_pepl15_allel27_wind10_03_03_2026..csv\
# netMHC_II_pepl15_allel27_wind30_03_03_2026.csv\
# \
# The files are called netMHC_II and not CD4Episcore, because these two tools can be ran together and scores saved into one file. Therefore the file got the name from one of the tools.
#
#
#
# For each tool_output with different settings a ranking from 1 to 37 will be done, each antibody will hence be given a number 1 to 37
# This ranking will be compared to the known/ clinically determined immunigenecity ranking of the antibodies. The clinical immunigenecity ranking is based on anti-drug antibody (ADA) data. The two nanobodies will be held outside the ranking since they have risk of behaving differently, and special intreset is taken in how the tool perform at prediction those.
#
# For each setting three measurments on how good they perform will be calculated:
#     1. Mean absolute rank error (MARE) for antibodies
#     2. Spearman rank correlation
#     3. Mean absolute rank error for the two nanobodies
#
# 1. MARE is just the absolute difference between the known rank of the antibody and the predicted rank
# 2. Spearman rank correlation is a statistical test that can compare two lists of ranking and tell how well they align. 1 is a perfect correlation
# 0 means no relation between the two variables (no correlation, random) and -1 is a perfect reversed correlation (very bad).
# 3. Same calculation as for 1, but separated from the rest. Here a separate ranking where the 2 nanobodies are included are performed, hence antobodies and nanobodies get a number 1 to 39 and the MARE for the nanobodies is calculated.

# %%
import pandas as pd
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

# %%
# Load the tool outputs with the different setttings, store each in a separate pandas DataFrame
CD4Episcore_immunogenComb_pepl11_allel27_wind2 = pd.read_csv("tool_outputs/netMHC_II_pepl11_allel27_wind2_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl12_allel27_wind2 = pd.read_csv("tool_outputs/netMHC_II_pepl12_allel27_wind2_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl12_allel27_wind5 = pd.read_csv("tool_outputs/netMHC_II_pepl12_allel27_wind5_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl12_allel27_wind10 = pd.read_csv("tool_outputs/netMHC_II_pepl12_allel27_wind10_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl15_allel27_wind2 = pd.read_csv("tool_outputs/netMHC_II_pepl15_allel27_wind2_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl15_allel27_wind10 = pd.read_csv("tool_outputs/netMHC_II_pepl15_allel27_wind10_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl15_allel27_wind30 = pd.read_csv("tool_outputs/netMHC_II_pepl15_allel27_wind30_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl15_allel7_wind5 = pd.read_csv("tool_outputs/netMHC_II_pepl15_allel7_wind5_03_03_2026.csv")
CD4Episcore_immunogenComb_pepl11_allel7_wind2 = pd.read_csv("tool_outputs/netMHC_II_pepl11_allel7_wind2_03_03_2026.csv")


# Then also load the sequence table for each tool output. 
# This is because in the tool output of the scores each antibody sequence has just been given an number (1-39)
# With the sequence table I can map the antibody name back to the number it was given
seq_table_CD4Episcore_immunogenComb_pepl11_allel27_wind2 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl11_allel27_wind2_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl12_allel27_wind2 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl12_allel27_wind2_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl12_allel27_wind5 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl12_allel27_wind5_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl12_allel27_wind10 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl12_allel27_wind10_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl15_allel27_wind2 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl15_allel27_wind2_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl15_allel27_wind10 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl15_allel27_wind10_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl15_allel27_wind30 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl15_allel27_wind30_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl15_allel7_wind5 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl15_allel7_wind5_03_03_2026.csv")
seq_table_CD4Episcore_immunogenComb_pepl11_allel7_wind2 = pd.read_csv("tool_outputs/sequence_table_netMHC_II_pepl11_allel7_wind2_03_03_2026.csv")

# %%
# Create dictionary with all df names too be able to loop through them
all_dfs = {
    'CD4Episcore_immunogenComb_pepl11_allel27_wind2': CD4Episcore_immunogenComb_pepl11_allel27_wind2,
    'CD4Episcore_immunogenComb_pepl12_allel27_wind2': CD4Episcore_immunogenComb_pepl12_allel27_wind2,
    'CD4Episcore_immunogenComb_pepl12_allel27_wind5': CD4Episcore_immunogenComb_pepl12_allel27_wind5,
    'CD4Episcore_immunogenComb_pepl12_allel27_wind10': CD4Episcore_immunogenComb_pepl12_allel27_wind10,
    'CD4Episcore_immunogenComb_pepl15_allel27_wind2': CD4Episcore_immunogenComb_pepl15_allel27_wind2,
    'CD4Episcore_immunogenComb_pepl15_allel27_wind10': CD4Episcore_immunogenComb_pepl15_allel27_wind10,
    'CD4Episcore_immunogenComb_pepl15_allel27_wind30': CD4Episcore_immunogenComb_pepl15_allel27_wind30,
    'CD4Episcore_immunogenComb_pepl15_allel7_wind5': CD4Episcore_immunogenComb_pepl15_allel7_wind5,
    'CD4Episcore_immunogenComb_pepl11_allel7_wind2': CD4Episcore_immunogenComb_pepl11_allel7_wind2
}

seq_tables = {
    'CD4Episcore_immunogenComb_pepl11_allel27_wind2': seq_table_CD4Episcore_immunogenComb_pepl11_allel27_wind2,
    'CD4Episcore_immunogenComb_pepl12_allel27_wind2': seq_table_CD4Episcore_immunogenComb_pepl12_allel27_wind2,
    'CD4Episcore_immunogenComb_pepl12_allel27_wind5': seq_table_CD4Episcore_immunogenComb_pepl12_allel27_wind5,
    'CD4Episcore_immunogenComb_pepl12_allel27_wind10':seq_table_CD4Episcore_immunogenComb_pepl12_allel27_wind10,
    'CD4Episcore_immunogenComb_pepl15_allel27_wind2': seq_table_CD4Episcore_immunogenComb_pepl15_allel27_wind2,
    'CD4Episcore_immunogenComb_pepl15_allel27_wind10': seq_table_CD4Episcore_immunogenComb_pepl15_allel27_wind10,
    'CD4Episcore_immunogenComb_pepl15_allel27_wind30': seq_table_CD4Episcore_immunogenComb_pepl15_allel27_wind30,
    'CD4Episcore_immunogenComb_pepl15_allel7_wind5': seq_table_CD4Episcore_immunogenComb_pepl15_allel7_wind5,
    'CD4Episcore_immunogenComb_pepl11_allel7_wind2': seq_table_CD4Episcore_immunogenComb_pepl11_allel7_wind2
    
}

# %%
# Sanity check
# Check so that all dataframes have all the 39 antibodies and the 27 alleles
for name, df in all_dfs.items():
    # check if unique values in seq # column is 39)
    if df['seq #'].nunique()!=39:
        print(f'{name, "does not have 39 antibodies/nanobodies"}')
    else:
        # check if number of unique valies in HLA allele column is 27)
        if df['allele'].nunique()==27:
            print(f'{name,"has 27 HLA alleles"}')
        elif df['allele'].nunique()==7:
            print(f'{name,"has 7 HLA alleles"}')
        elif df['allele'].nunique()==1:
            print(f'{name,"has 1 HLA allele"}')
        else:
            print(f'{name,"does not have 27 or 7 HLA alleles"}')
# Out:
# ('CD4Episcore_immunogenComb_pepl11_allel27_wind2', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl12_allel27_wind2', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl12_allel27_wind5', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl12_allel27_wind10', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl15_allel27_wind2', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl15_allel27_wind10', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl15_allel27_wind30', 'has 27 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl15_allel7_wind5', 'has 7 HLA alleles')
# ('CD4Episcore_immunogenComb_pepl11_allel7_wind2', 'has 7 HLA alleles')

# %%
# Clean dataframes a bit, and instert the correct antibody names

for key in all_dfs:
    df = all_dfs[key]
    seq_table = seq_tables[key] 

    # Insert the sequence names (Antibody names) into the dataframe with scores, map by seq #, which exists in both dataframes
    df = df.merge(seq_table[['seq #', 'sequence name']], how='left')

    # Rename the column "sequence name" to "Antibody", 
    df.rename(columns={'sequence name': 'Antibody'}, inplace=True)

    # remove the two columns called seq # from the calc_rank_table
    df = df.drop(columns=['seq #'])

    # Place the anotbody columns as the first column beacuse its easier to read

    # Remove the last column and save it as a variable
    last_col = df.pop(df.columns[-1])
    # Insert the column as the first column
    df.insert(0, last_col.name, last_col)

    all_dfs[key] = df

# %%
all_dfs['CD4Episcore_immunogenComb_pepl11_allel7_wind2'].head()
# Out:
#        Antibody      peptide  start  end  peptide length          allele  \
# 0   LANADELUMAB  KLLIYKASTLE    167  177              11  HLA-DRB1*15:01
# 1  BENRALIZUMAB  PKLLIYHTSRL    165  175              11  HLA-DRB1*15:01
# 2    RESLIZUMAB  KLLIYGANSLQ    161  171              11  HLA-DRB1*15:01
# 3   BOCOCIZUMAB  KLLIYSASYRY    163  173              11  HLA-DRB1*15:01
# 4     SARILUMAB  KLLIYGASSLE    161  171              11  HLA-DRB1*15:01
#
#    peptide index  median binding percentile netmhciipan_ba core  \
# 0           3040                       0.01           LLIYKASTL
# 1           3255                       0.01           LLIYHTSRL
# 2           1829                       0.01           LLIYGANSL
# 3           3922                       0.01           LLIYSASYR
# 4           2820                       0.04           LLIYGASSL
#
#    netmhciipan_ba ic50  netmhciipan_ba percentile cd4episcore core  \
# 0               105.11                       0.01        KLLIYKAST
# 1                96.33                       0.01        PKLLIYHTS
# 2                73.25                       0.01        LLIYGANSL
# 3               116.23                       0.01        LLIYSASYR
# 4               211.80                       0.04        KLLIYGASS
#
#   immunogenicity score immunogenicity combined score
# 0              99.8995                       44.5798
# 1              99.0665                       43.5866
# 2              99.6464                      43.09856
# 3              96.6357                      39.04428
# 4              99.9798                      47.79192

# %% [markdown]
# Here the score is calculated as nr of rows with netMHCpan percentile <=10, divided by total number of rows. Meaning that higher number indicated higher immunogenicity. The score can be described as the percentage of MHC-peptides that have a netMHCpan percentile below 10

# %%
# for all dfs in all_dfs, check the dtype of the column "immunogenicity score"
for key, df in all_dfs.items():
    print(f'{key}: {df["immunogenicity combined score"].dtype}')
# Out:
# CD4Episcore_immunogenComb_pepl11_allel27_wind2: object
# CD4Episcore_immunogenComb_pepl12_allel27_wind2: object
# CD4Episcore_immunogenComb_pepl12_allel27_wind5: object
# CD4Episcore_immunogenComb_pepl12_allel27_wind10: object
# CD4Episcore_immunogenComb_pepl15_allel27_wind2: float64
# CD4Episcore_immunogenComb_pepl15_allel27_wind10: float64
# CD4Episcore_immunogenComb_pepl15_allel27_wind30: float64
# CD4Episcore_immunogenComb_pepl15_allel7_wind5: float64
# CD4Episcore_immunogenComb_pepl11_allel7_wind2: object

# %%
for key, df in all_dfs.items():
    if df["immunogenicity combined score"].dtype == "object":
        print(f"\nChecking {key}")
        
        non_numeric = df[
            pd.to_numeric(df["immunogenicity combined score"], errors="coerce").isna()
        ]["immunogenicity score"].unique()
        
        print("Non-numeric values found:")
        print(non_numeric[:20])  # show first 20 unique bad values

        print(df[df["immunogenicity combined score"] == "-"].shape[0])
        print(df.shape[0])
# Out:
# Checking CD4Episcore_immunogenComb_pepl11_allel27_wind2
# Non-numeric values found:
# ['-']
# 4563
# 114183
#
# Checking CD4Episcore_immunogenComb_pepl12_allel27_wind2
# Non-numeric values found:
# ['-']
# 783
# 113670
#
# Checking CD4Episcore_immunogenComb_pepl12_allel27_wind5
# Non-numeric values found:
# ['-']
# 378
# 45819
#
# Checking CD4Episcore_immunogenComb_pepl12_allel27_wind10
# Non-numeric values found:
# ['-']
# 270
# 23166
#
# Checking CD4Episcore_immunogenComb_pepl11_allel7_wind2
# Non-numeric values found:
# ['-']
# 1183
# 29603

# %%
# for all_dfs netMHC_II_immunogenComb_pepl12_allel27_wind10 print the rows where the immunogenicity score is equal to "-"
all_dfs['CD4Episcore_immunogenComb_pepl12_allel27_wind10'][all_dfs['CD4Episcore_immunogenComb_pepl12_allel27_wind10']['immunogenicity combined score'] == '-']
# Out:
#           Antibody       peptide  start  end  peptide length  \
# 2276   MEPOLIZUMAB  KDTSRNQVVLTM     71   82              12
# 3368     DUPILUMAB  LEQPGGSLRLSC     11   22              12
# 3482     RITUXIMAB  EDAATYYCQQWT    201  212              12
# 5154   MEPOLIZUMAB  KDTSRNQVVLTM     71   82              12
# 7129     RITUXIMAB  EDAATYYCQQWT    201  212              12
# ...            ...           ...    ...  ...             ...
# 23161  VISILIZUMAB  SSNPPTFGGGTK    211  222              12
# 23162  VISILIZUMAB  SSNPPTFGGGTK    211  222              12
# 23163  VISILIZUMAB  SSNPPTFGGGTK    211  222              12
# 23164  VISILIZUMAB  SSNPPTFGGGTK    211  222              12
# 23165  VISILIZUMAB  SSNPPTFGGGTK    211  222              12
#
#                           allele  peptide index  median binding percentile  \
# 2276              HLA-DRB3*02:02            318                       15.0
# 3368   HLA-DQA1*05:01/DQB1*03:01            512                       21.0
# 3482   HLA-DQA1*01:01/DQB1*05:01            731                       21.0
# 5154              HLA-DRB1*13:02            318                       29.0
# 7129   HLA-DQA1*03:01/DQB1*03:02            731                       38.0
# ...                          ...            ...                        ...
# 23161             HLA-DRB3*01:01             44                      100.0
# 23162  HLA-DQA1*01:01/DQB1*05:01             44                      100.0
# 23163             HLA-DRB3*02:02             44                      100.0
# 23164             HLA-DRB1*03:01             44                      100.0
# 23165  HLA-DPA1*02:01/DPB1*14:01             44                      100.0
#
#       netmhciipan_ba core  netmhciipan_ba ic50  netmhciipan_ba percentile  \
# 2276            TSRNQVVLT              9811.23                       15.0
# 3368            QPGGSLRLS              3396.90                       21.0
# 3482            AATYYCQQW              6132.10                       21.0
# 5154            TSRNQVVLT              6098.56                       29.0
# 7129            AATYYCQQW              6618.73                       38.0
# ...                   ...                  ...                        ...
# 23161           SNPPTFGGG             40639.83                      100.0
# 23162           SNPPTFGGG             41061.04                      100.0
# 23163           SNPPTFGGG             41961.54                      100.0
# 23164           PPTFGGGTK             42228.43                      100.0
# 23165           SNPPTFGGG             42964.45                      100.0
#
#       cd4episcore core immunogenicity score immunogenicity combined score
# 2276                 -                    -                             -
# 3368                 -                    -                             -
# 3482                 -                    -                             -
# 5154                 -                    -                             -
# 7129                 -                    -                             -
# ...                ...                  ...                           ...
# 23161                -                    -                             -
# 23162                -                    -                             -
# 23163                -                    -                             -
# 23164                -                    -                             -
# 23165                -                    -                             -
#
# [270 rows x 14 columns]

# %%
# Remove all rows where the immunogenicity score is equal to "-"
# And make the immunogenicity score column numeric instead of object
for key in all_dfs:
    df = all_dfs[key]
    df = df[df['immunogenicity combined score'] != '-']
    df['immunogenicity combined score'] = pd.to_numeric(df['immunogenicity combined score'], errors='coerce')
    all_dfs[key] = df

all_dfs['CD4Episcore_immunogenComb_pepl12_allel27_wind10'].head()
# Out:
# C:\Users\rebbe\AppData\Local\Temp\ipykernel_15660\965174889.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['immunogenicity combined score'] = pd.to_numeric(df['immunogenicity combined score'], errors='coerce')
#        Antibody       peptide  start  end  peptide length  \
# 0    RESLIZUMAB  KLLIYGANSLQT    161  172              12
# 1   VISILIZUMAB  TLTISSLQPEDF    191  202              12
# 2  GALCANEZUMAB  TLTISSLQPEDF    191  202              12
# 3   USTEKINUMAB  TLTISSLQPEDF    191  202              12
# 4    IBALIZUMAB  LTISSVQAEDVA    201  212              12
#
#                       allele  peptide index  median binding percentile  \
# 0             HLA-DRB1*15:01            372                       0.01
# 1  HLA-DQA1*05:01/DQB1*02:01             42                       0.02
# 2  HLA-DQA1*05:01/DQB1*02:01            419                       0.02
# 3  HLA-DQA1*05:01/DQB1*02:01            508                       0.02
# 4  HLA-DQA1*05:01/DQB1*02:01            155                       0.02
#
#   netmhciipan_ba core  netmhciipan_ba ic50  netmhciipan_ba percentile  \
# 0           LLIYGANSL                57.66                       0.01
# 1           ISSLQPEDF               106.22                       0.02
# 2           ISSLQPEDF               106.22                       0.02
# 3           ISSLQPEDF               106.22                       0.02
# 4           ISSVQAEDV               104.14                       0.02
#
#   cd4episcore core immunogenicity score  immunogenicity combined score
# 0        KLLIYGANS              98.9982                       43.07928
# 1        ISSLQPEDF              99.8586                       56.74344
# 2        ISSLQPEDF              99.8586                       56.74344
# 3        ISSLQPEDF              99.8586                       56.74344
# 4        ISSVQAEDV               98.475                       54.39000

# %%
# Loop through all the dataframes, and calculate the mean of the immunogenicity score for each antibody.
# Overwrite the old dataframe and put the antibody name + the immunogen as the columns 
for key, df in all_dfs.items():
    score_df = (
        df.groupby('Antibody')['immunogenicity combined score']
        .mean()
        .reset_index(name='mean_immunogenicity_combined_score')

    )

    all_dfs[key] = score_df # overwrite the old df

# %%
# For all the dataframes in the all_dfs dictionary loop through them and make a copy 
# without the two rows where Antibody = Caplacizumab or Vobarilizumab
# Put the new dataframes into a new dictionary called all_dfs_AB

# we need to do this because we don't want these two nanobodies to be ranked, 
# but we also don't want them to mess with the ranking of the other antibodies

all_dfs_AB = {}

for name, df in all_dfs.items():
    # make a new dictionary with a copy of the dataframes but without the two nanobodies
    all_dfs_AB[name + "_AB"] = df.loc[~df['Antibody'].isin(['Caplacizumab', 'Vobarilizumab'])].copy()

# Check so it worked
all_dfs_AB.keys()
all_dfs_AB['CD4Episcore_immunogenComb_pepl12_allel27_wind10_AB'].tail()
# Out:
#          Antibody  mean_immunogenicity_combined_score
# 33    SECUKINUMAB                           70.622040
# 34  TILDRAKIZUMAB                           73.910618
# 35    USTEKINUMAB                           71.681867
# 36    VEDOLIZUMAB                           71.664063
# 37    VISILIZUMAB                           72.766404

# %%
# Now add a column to the all_dfs_AB dataframe called ranked by tool, where the percent_immonogen values are ranked from highest to lowest
# Highest means highest immunogenicity, so thats 37.
for df in all_dfs_AB.values():
    df['ranked_by_tool'] = df['mean_immunogenicity_combined_score'].rank(ascending=True, method='average')

# Do the same for the df includning the two nanobodies
for df in all_dfs.values():
    df['ranked_by_tool'] = df['mean_immunogenicity_combined_score'].rank(ascending=True, method='average')

# %%
# Load the ADA ranking
ADA_rank = {
'BEZLOTOXUMAB':1,
'VISILIZUMAB':2,
'OMALIZUMAB':3,
'EVOLOCUMAB':4,
'SECUKINUMAB':5,
'DENOSUMAB':6,
'IBALIZUMAB':7,
'OCRELIZUMAB':8,
'FREMANEZUMAB':9,
'BASILIXIMAB':10,
'PALIVIZUMAB':11,
'CANAKINUMAB':12,
'ECULIZUMAB':13,
'BRODALUMAB':14,
'MEPOLIZUMAB':15,
'GUSELKUMAB':16,
'RESLIZUMAB':17,
'ALIROCUMAB':18,
'GALCANEZUMAB':19,
'VEDOLIZUMAB':20,
'EFALIZUMAB':21,
'TILDRAKIZUMAB':22,
'USTEKINUMAB':23,
'DUPILUMAB':24,
'ERENUMAB':25,
'SARILUMAB':26,
'NATALIZUMAB':27,
'Caplacizumab':28,
'LANADELUMAB':29,
'BUROSUMAB':30,
'BENRALIZUMAB':31,
'ADALIMUMAB':32,
'IXEKIZUMAB':33,
'RITUXIMAB':34,
'INFLIXIMAB':35,
'GOLIMUMAB':36,
'Vobarilizumab':37,
'BOCOCIZUMAB':38,
'ALEMTUZUMAB':39
}

# create antoher dictionary where the two nanobdoies are removed 
ADA_rank_AB = {
'BEZLOTOXUMAB':1,
'VISILIZUMAB':2,
'OMALIZUMAB':3,
'EVOLOCUMAB':4,
'SECUKINUMAB':5,
'DENOSUMAB':6,
'IBALIZUMAB':7,
'OCRELIZUMAB':8,
'FREMANEZUMAB':9,
'BASILIXIMAB':10,
'PALIVIZUMAB':11,
'CANAKINUMAB':12,
'ECULIZUMAB':13,
'BRODALUMAB':14,
'MEPOLIZUMAB':15,
'GUSELKUMAB':16,
'RESLIZUMAB':17,
'ALIROCUMAB':18,
'GALCANEZUMAB':19,
'VEDOLIZUMAB':20,
'EFALIZUMAB':21,
'TILDRAKIZUMAB':22,
'USTEKINUMAB':23,
'DUPILUMAB':24,
'ERENUMAB':25,
'SARILUMAB':26,
'NATALIZUMAB':27,
'LANADELUMAB':28,
'BUROSUMAB':29,
'BENRALIZUMAB':30,
'ADALIMUMAB':31,
'IXEKIZUMAB':32,
'RITUXIMAB':33,
'INFLIXIMAB':34,
'GOLIMUMAB':35,
'BOCOCIZUMAB':36,
'ALEMTUZUMAB':37
}

# %%
# Add the ADA rank to the dfs
# AntiBody df
for df in all_dfs_AB.values():
    df['ADA_rank'] = df['Antibody'].map(ADA_rank_AB)

# Nanobody df
for df in all_dfs.values():
    df['ADA_rank'] = df['Antibody'].map(ADA_rank)

# %%
# Compute MARE for the AB dataframes

# Add a column called MARE, for each row add the value for the absolute difference between the ranked_by_tool and ADA_rank
for df in all_dfs_AB.values():
    df['MARE'] = (df['ranked_by_tool'] - df['ADA_rank']).abs()

# Do the same thing for the dataframes with the nanobodies
for df in all_dfs.values():
    df['MARE'] = df['ranked_by_tool'] - df['ADA_rank']

# %%
# Create a ranked_score_table df with coulmns, datadframe (with all df names from all_dfs_AB),
# The sum of MARE for each df, 
# The spearman rank correlation between ranked by tool and ADA rank,
# The MARE for Caplacizumab and Vobarilizumab
ranked_score_table = pd.DataFrame({
    'dataframe': list(all_dfs_AB.keys()),
    'sum_MARE': [df['MARE'].sum() for df in all_dfs_AB.values()],
    'spearmanr': [spearmanr(df['ranked_by_tool'], df['ADA_rank']).correlation for df in all_dfs_AB.values()],
    'spearmanr_pval': [spearmanr(df['ranked_by_tool'], df['ADA_rank']).pvalue for df in all_dfs_AB.values()],
    'Caplacizumab_MARE': [df.loc[df['Antibody'] == 'Caplacizumab', 'MARE'].values[0] for df in all_dfs.values()],
    'Vobarilizumab_MARE': [df.loc[df['Antibody'] == 'Vobarilizumab', 'MARE'].values[0] for df in all_dfs.values()]
    
})

# save the ranked_score_table as a csv file
ranked_score_table.to_csv('ranked_score_table.csv', index=False)
ranked_score_table
# Out:
#                                            dataframe  sum_MARE  spearmanr  \
# 0  CD4Episcore_immunogenComb_pepl11_allel27_wind2_AB     518.0  -0.261024
# 1  CD4Episcore_immunogenComb_pepl12_allel27_wind2_AB     528.0  -0.233997
# 2  CD4Episcore_immunogenComb_pepl12_allel27_wind5_AB     524.0  -0.237316
# 3  CD4Episcore_immunogenComb_pepl12_allel27_wind1...     466.0  -0.072072
# 4  CD4Episcore_immunogenComb_pepl15_allel27_wind2_AB     554.0  -0.344239
# 5  CD4Episcore_immunogenComb_pepl15_allel27_wind1...     548.0  -0.365339
# 6  CD4Episcore_immunogenComb_pepl15_allel27_wind3...     438.0  -0.020389
# 7   CD4Episcore_immunogenComb_pepl15_allel7_wind5_AB     574.0  -0.419393
# 8   CD4Episcore_immunogenComb_pepl11_allel7_wind2_AB     516.0  -0.251541
#
#    spearmanr_pval  Caplacizumab_MARE  Vobarilizumab_MARE
# 0        0.118655               -5.0               -25.0
# 1        0.163337               -7.0               -23.0
# 2        0.157277              -11.0               -26.0
# 3        0.671637               11.0               -12.0
# 4        0.036952              -21.0               -28.0
# 5        0.026183                7.0               -11.0
# 6        0.904661               -8.0               -35.0
# 7        0.009770              -12.0               -25.0
# 8        0.133145              -12.0               -25.0

# %%
# plot spearman rank score for each setting
plt.bar(ranked_score_table['dataframe'], ranked_score_table['spearmanr'])
plt.xticks(rotation=45, ha='right')
plt.ylabel('Spearman rank score', size=15)
plt.title("CD4Episcore Immunogenicity combined score", size=20)
# Out:
# Text(0.5, 1.0, 'CD4Episcore Immunogenicity combined score')
